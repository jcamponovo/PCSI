# %%
# %matplotlib notebook
#En dynamique
from math import cos,pi,sin,atan2,asin,acos
import matplotlib.pyplot as plt
from ipywidgets import interact, widgets



fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
fig.show() 
    
def trace():
    global t
    xcos=[]
    xsin=[]
    xsomme=[]
    x2=[]
    for val in t:
        xcos.append(f1(val))
        xsin.append(f2(val))
        xsomme.append(xcos[-1]+xsin[-1])
        x2.append(f3(val))
    ax1.clear()
    ax2.clear()
      
    ax1.spines['right'].set_color('none')
    ax1.spines['top'].set_color('none')
    ax1.spines['bottom'].set_position(('data',0))
    ax1.spines['left'].set_position(('data',0))
    ax1.xaxis.set_ticks_position('bottom')
    ax1.yaxis.set_ticks_position('left')
    ax1.set_xlabel("t (en s)")
    ax1.set_ylabel("x (en m)")
    ax1.set_xlim([0,20])
    ax1.set_ylim([-0.11,0.11])#[min(-0.025,li-1.05*xm),li+1.05*xm])
    ax1.set_xticks([0,10,20])
    
    ax1.plot(t,xcos,"blue",label="$A\cos(\omega t)$")
    ax1.plot(t,xsin,"red",label="$B\sin(\omega t)$")
    ax1.plot(t,xsomme,"green",label="$A\cos(\omega t)+B\sin(\omega t)$")
    ax1.legend(framealpha=1.)
    
    
    ax2.spines['right'].set_color('none')
    ax2.spines['top'].set_color('none')
    ax2.spines['bottom'].set_position(('data',0))
    ax2.spines['left'].set_position(('data',0))
    ax2.xaxis.set_ticks_position('bottom')
    ax2.yaxis.set_ticks_position('left')
    ax2.set_xlabel("t (en s)")
    ax2.set_ylabel("x (en m)")
    ax2.set_xlim([0,20])
    ax2.set_ylim([-0.11,0.11])#[min(-0.025,li-1.05*xm),li+1.05*xm])
    ax2.set_xticks([0,10,20])
    
    ax2.plot(t,x2,"green",label="$C\cos(\omega t + \phi)$")
    ax2.legend(framealpha=1.)
  
@interact(n1=(1.,2.5,0.01),n2=(1.,2.5,0.01),i1=(0.,90.,0.1))
def setparam(n1=1,n2=1.33,i1=45.):
    global A,B,omega,phi,C
    ax1.clear()
    ax1.set_xlim([-1,1])
    ax1.plot([-1,1],[0,0],"black")
    ax1.plot([0,0],[-1,1],"k--")
    R1=1/cos(i1*pi/180)
    x1=-R1*sin(i1*pi/180)
    try:
        i2 = 180/pi*asin(n1/n2*sin(i1*pi/180))
        R2=-1/cos(i2*pi/180)
        x2=abs(R2*sin(i2*pi/180))
        
        ax1.plot([x1,0,x2],[1,0,-1],"red")
        ax1.plot([0,-x1],[0,1],"r--")
        plt.text(-0.8,-0.8,'i2 = {:.2f} et r = {:.2f}'.format(i2,i1),horizontalalignment='center',
     verticalalignment='center',fontsize=12, color='k')
        plt.text(0.05,-0.15,'i2',horizontalalignment='center',
     verticalalignment='center',fontsize=12, color='k')
    except:
        ax1.plot([x1,0,-x1],[1,0,1],"red")
        plt.text(-0.8,-0.8,'Reflexion totale et r = {:.2f}'.format(i1),horizontalalignment='center',
     verticalalignment='center',fontsize=12, color='k')
        
    ax1.spines['right'].set_color('none')
    ax1.spines['top'].set_color('none')
    ax1.spines['left'].set_color('none')
    ax1.spines['bottom'].set_color('none')
    ax1.set_xticks([])
    ax1.set_yticks([])
    plt.text(-0.05,0.15,'i1',horizontalalignment='center',
     verticalalignment='center',fontsize=12, color='k')
    plt.text(0.05,0.15,'r',horizontalalignment='center',
     verticalalignment='center',fontsize=12, color='k')
    plt.text(0.8,0.8,'milieu 1',horizontalalignment='center',
     verticalalignment='center',fontsize=12, color='k')
    plt.text(0.8,-0.8,'milieu 2',horizontalalignment='center',
     verticalalignment='center',fontsize=12, color='k')
setparam()
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=1.0, description='n1', max=2.5, min=1.0, step=0.01), FloatSlider(value…
